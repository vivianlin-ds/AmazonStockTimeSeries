# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/AAPL_Stock_Price_Dataset.csv')
df.shape
# Out:
# (11354, 9)

# %%
df.describe()
# Out:
#                                 Date          Open          High  \
# count                          11354  11354.000000  11354.000000
# mean   2003-06-13 07:15:16.329047168     27.944977     28.247652
# min              1980-12-15 00:00:00      0.038072      0.038072
# 25%              1992-03-06 18:00:00      0.245930      0.252180
# 50%              2003-06-10 12:00:00      0.481131      0.491290
# 75%              2014-09-17 18:00:00     21.481897     21.733548
# max              2025-12-31 00:00:00    286.200012    288.619995
# std                              NaN     57.766472     58.385872
#
#                 Low         Close        Volume  Daily_Return   Price_Range  \
# count  11354.000000  11354.000000  1.135400e+04  11353.000000  11354.000000
# mean      27.661508     27.967625  3.097171e+08      0.109127      0.586144
# min        0.037645      0.037645  0.000000e+00    -51.869203      0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Daily_Return    1
# Price_Range     0
# Price_Change    0
# dtype: int64

# %%
df.dtypes
# Out:
# Date             object
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Volume            int64
# Daily_Return    float64
# Price_Range     float64
# Price_Change    float64
# dtype: object

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close     Volume  \
# 0  1980-12-15  0.093684  0.093684  0.093256  0.093256  175884800
# 1  1980-12-16  0.086839  0.086839  0.086412  0.086412  105728000
# 2  1980-12-17  0.088550  0.088978  0.088550  0.088550   86441600
# 3  1980-12-18  0.091118  0.091545  0.091118  0.091118   73449600
# 4  1980-12-19  0.096678  0.097106  0.096678  0.096678   48630400
#
#    Daily_Return  Price_Range  Price_Change
# 0           NaN     0.000428     -0.000428
# 1     -7.339797     0.000428     -0.000428
# 2      2.475132     0.000428      0.000000
# 3      2.899260     0.000428      0.000000
# 4      6.102835     0.000428      0.000000

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Date            datetime64[ns]
# Open                   float64
# High                   float64
# Low                    float64
# Close                  float64
# Volume                   int64
# Daily_Return           float64
# Price_Range            float64
# Price_Change           float64
# dtype: object

# %% [markdown]
# Minimal cleaning needed for the dataset, but use the past 25 years for prediction.

# %%
final_df = df[df['Date'] >= '2000-01-01']
final_df.shape
# Out:
# (6539, 9)

# %%
final_df.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           6539  6539.000000  6539.000000  6539.000000
# mean   2012-12-31 14:04:31.968190976    48.357378    48.879909    47.868249
# min              2000-01-03 00:00:00     0.194792     0.197791     0.190743
# 25%              2006-07-05 12:00:00     2.154106     2.175700     2.119617
# 50%              2013-01-02 00:00:00    15.794348    16.015226    15.660722
# 75%              2019-07-01 12:00:00    51.358242    52.009656    50.827629
# max              2025-12-31 00:00:00   286.200012   288.619995   283.299988
# std                              NaN    69.367421    70.110528    68.693655
#
#              Close        Volume  Daily_Return  Price_Range  Price_Change
# count  6539.000000  6.539000e+03   6539.000000  6539.000000   6539.000000
# mean     48.396738  3.732367e+08      0.120399     1.011660      0.039360
# ...

# %%
final_df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Daily_Return',
#        'Price_Range', 'Price_Change'],
#       dtype='object')

# %%
final_df.head()
# Out:
#            Date      Open      High       Low     Close     Volume  \
# 4815 2000-01-03  0.786328  0.843498  0.762429  0.839281  535796800
# 4816 2000-01-04  0.811633  0.829440  0.758680  0.768521  512377600
# 4817 2000-01-05  0.777892  0.828971  0.772270  0.779767  778321600
# 4818 2000-01-06  0.795700  0.802260  0.712287  0.712287  767972800
# 4819 2000-01-07  0.723534  0.757274  0.716036  0.746027  460734400
#
#       Daily_Return  Price_Range  Price_Change
# 4815      8.875354     0.081069      0.052953
# 4816     -8.431023     0.070760     -0.043112
# 4817      1.463334     0.056702      0.001874
# 4818     -8.653835     0.089973     -0.083413
# 4819      4.736869     0.041238      0.022493
